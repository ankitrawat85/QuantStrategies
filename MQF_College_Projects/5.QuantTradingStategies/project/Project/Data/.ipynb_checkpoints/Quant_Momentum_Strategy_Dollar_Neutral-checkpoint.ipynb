# %%
import pandas as pd
import numpy  as  np
from datetime import datetime, timedelta

# %% [markdown]
# ### 1. Data Download

# %%
fx_df = pd.read_csv("G10_FX_HI_LO_CLOSE.csv", skiprows=0, header = None)
i = 1 
print("list of Currencies:")
while (i < fx_df.shape[1]):
    columns_list = [0]
    columns_list.append(i)
    for j in range(i+1,x.shape[1],1):
        if (x[i][0] == x[j][0]):
            columns_list.append(j)
            if (j == fx_df .shape[1]-1):
                print(fx_df [i][0])
                df_ = pd.read_csv('G10_FX_HI_LO_CLOSE.csv', usecols =columns_list,skiprows=1,header =0)
                df_["Dates"] = pd.to_datetime(df_["Dates"])
                df_.set_index("Dates")
                df_.columns = ["Dates","High","Low","Last"]
                df_.to_csv(f'FX_{x[i][0]}.csv')
                break
            
        else:
            print(x[i][0])
            df_ = pd.read_csv('G10_FX_HI_LO_CLOSE.csv', usecols =columns_list,skiprows=1,header =0)
            df_["Dates"] = pd.to_datetime(df_["Dates"])
            df_.set_index("Dates")
            df_.columns = ["Dates","High","Low","Last"]
            df_.to_csv(f'FX_{x[i][0]}.csv')
            break
    

    if ( j == x.shape[1]-1):
        break
    else:
        i = j 
        columns_list.clear()

# %%
FX_SEK =  pd.read_csv("FX_SEK.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_DKK =  pd.read_csv("FX_DKK.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_CHF =  pd.read_csv("FX_CHF.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_NZD =  pd.read_csv("FX_NZD.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_AUD =  pd.read_csv("FX_AUD.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_CAD=  pd.read_csv("FX_CAD.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_GBP=  pd.read_csv("FX_GBP.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_JPY = pd.read_csv("FX_EUR.csv", skiprows=0, index_col ="Dates").iloc[:,1:]
FX_EUR = pd.read_csv("FX_EUR.csv", skiprows=0, index_col ="Dates").iloc[:,1:]

# %%
"""## CLose Price
close_df = pd.concat([FX_SEK["Last"],FX_DKK["Last"],FX_CHF["Last"],FX_NZD["Last"] ,FX_AUD["Last"],FX_CAD["Last"],FX_GBP["Last"],FX_JPY["Last"],FX_EUR["Last"]],axis =1)
close_df.columns = {"FX_SEK","FX_DKK","FX_CHF","FX_NZD","FX_AUD","FX_CAD","FX_GBP","FX_JPY","FX_EUR"}"""

# %%
def GetYZVolatility(history):
    '''
    Yang and Zhang 'Drift-Independent Volatility Estimation'

    Formula: sigma_YZ^2 = sigma_OJ^2 + self.k * sigma_SD^2 + (1-self.k)*sigma_RS^2 (Equation 20 in [1])
        where,  sigma_OJ - (Overnight Jump Volitility estimator)
                sigma_SD - (Standard Volitility estimator)
                sigma_RS - (Rogers and Satchell Range Volatility estimator)'''
    #YZ_volatility = []
    
    #time_index = history.index
    #today = time_index[-1]
    
    #time_index = history.loc[available_symbols[0]].index
    #today = time_index[-1]
    #print(time_index)
    #print(today)
    #past_month_ohlc = (pd.to_datetime(all_df.index[-1]) - timedelta(days=30)).strftime('%Y-%m-%d')
    #past_month_ohlc = history.loc[ticker].loc[today - timedelta(self.OneMonth):today]


    """today = pd.to_datetime(all_df[0].index[-1]).strftime('%Y-%m-%d')
    print(today)
    diff = pd.to_datetime(pd.to_datetime(all_df[0].index[-1]) - timedelta(32)).strftime('%Y-%m-%d')
    print(diff)
    print(all_df[1].loc[diff:today])
    #print(all_df[1].loc['2021-05-20':'2021-06-22'])"""

    print("insde")
    YZ_volatility = []
    for i,j in enumerate(all_df):
        today = pd.to_datetime(all_df[i].index[-1]).strftime('%Y-%m-%d')
        diff = pd.to_datetime(pd.to_datetime(all_df[i].index[-1]) - timedelta(32)).strftime('%Y-%m-%d')
        past_month_ohlc = all_df[i].loc[diff:today]
        high,low,close,open = past_month_ohlc.High,past_month_ohlc.Low, past_month_ohlc.Last,past_month_ohlc.Last
        estimation_period = past_month_ohlc.shape[0]
        # Calculate constant parameter k for Yang and Zhang volatility estimator
        # using the formula found in Yang and Zhang (2000)
        k = 0.34 / (1.34 + (estimation_period + 1) / (estimation_period - 1))


        #sigma_OJ (overnight jump => stdev of close-to-open log returns)
        open_to_close_log_returns = np.log(close / close.shift(1))
        open_to_close_log_returns = open_to_close_log_returns[np.isfinite(open_to_close_log_returns)]
        sigma_OJ = np.std(open_to_close_log_returns)

        # sigma_SD (standard deviation of close-to-close log returns)
        close_to_close_log_returns = np.log(close / close.shift(1))
        close_to_close_log_returns = close_to_close_log_returns[np.isfinite(close_to_close_log_returns)]
        sigma_SD = np.std(close_to_close_log_returns)

            # sigma_RS (Rogers and Satchell (1991))
        h = np.log(high / open)
        l = np.log(low / open)
        c = np.log(close / open)
        sigma_RS_daily = (h * (h - c) + l * (l - c)) ** 0.5
        sigma_RS_daily = sigma_RS_daily[np.isfinite(sigma_RS_daily)]
        sigma_RS = np.mean(sigma_RS_daily)

            # daily Yang and Zhang volatility
        sigma_YZ = np.sqrt(sigma_OJ ** 2 + k * sigma_SD ** 2 + (1 - k) * sigma_RS ** 2)

            # append annualized volatility to the list
        YZ_volatility.append(sigma_YZ * np.sqrt(252))


        #print(all_df[i].iloc[da :today])
    return YZ_volatility
    # past_month_ohlc = (pd.to_datetime(all_df.index[-1]) - timedelta(days=30)).strftime('%Y-%m-%d')

# %%
GetYZVolatility(close_df)
# Out:
# insde
# [0.1480201864580566,
#  0.0953399143025246,
#  0.10246509546843095,
#  0.15253548568214184,
#  0.13442651520372792,
#  0.10226732193486733,
#  0.10968676546197269,
#  0.0940259827609974,
#  0.0940259827609974]

# %%
def GetTradingSignal(history):
    '''
    TREND Trading Signal
    - Uses the t-statistics of historical daily log-returns to reflect the strength of price movement trend
    - TREND Signal Conditions:
    t-stat > 1 => TREND Signal = 1
    t-stat < 1 => TREND Signal = -1
    -1 < t-stat < 1 => TREND Signal = t-stat
    '''
    settle = history
    # daily futures log-returns based on close-to-close
    log_returns = np.log(settle/settle.shift(1)).dropna()
    #print (log_returns)
    # Calculate the t-statistics as
    # (mean-0)/(stdev/sqrt(n)), where n is sample size
    mean = np.mean(log_returns)
    std = np.std(log_returns)
    n = len(log_returns)
    t_stat = mean/(std/np.sqrt(n))

    # cap holding at 1 and -1
    return np.clip(t_stat, a_max=1, a_min=-1)

# %%
GetTradingSignal(close_df)
# Out:
# FX_CHF    0.723931
# FX_SEK    0.422034
# FX_NZD   -0.039119
# FX_AUD   -0.294613
# FX_JPY   -0.906419
# FX_CAD    0.883175
# FX_GBP   -0.375208
# FX_EUR   -0.429830
# FX_DKK   -0.429830
# dtype: float64

# %%
('2021-06-22' - timedelta(days=1)).strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-326-fcc574cd8517> in <module>
# ----> 1 ('2021-06-22' - timedelta(days=1)).strftime('%Y-%m-%d')
#
# TypeError: unsupported operand type(s) for -: 'str' and 'datetime.timedelta'

# %%
(pd.to_datetime(FX_CHF.index[-1]) - timedelta(days=30)).strftime('%Y-%m-%d')
# Out:
# '2021-05-23'

# %%
GetTradingSignal(all_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-495-74efe5ea0036> in <module>
# ----> 1 GetTradingSignal(all_df)
#
# <ipython-input-494-395f3ccf6d83> in GetTradingSignal(history)
#      10     settle = history
#      11     # daily futures log-returns based on close-to-close
# ---> 12     log_returns = np.log(settle/settle.shift(1)).dropna()
#      13     #print (log_returns)
#      14     # Calculate the t-statistics as
#
# AttributeError: 'list' object has no attribute 'shift'

# %%
def OnData(close_df,all_df,available_symbols,portfolio_target_sigma):
    
    #print (history.head(5))
    print (available_symbols)
    N_assets = len(available_symbols)
    
    '''
    Monthly rebalance at the beginning of each month.
    Portfolio weights for each constituents are calculated based on Baltas and Kosowski weights.
    '''

    # skip if less than 30 days passed since the last trading date
    #if self.Time < self.nextRebalance:
     #   return

    '''Monthly Rebalance Execution'''
    """
    # dataframe that contains the historical data for all securities
    history = self.History(self.Securities.Keys, self.OneYear, Resolution.Daily)
    history.replace(0, np.nan, inplace=True)

    # Get the security symbols are are in the history dataframe
    available_symbols = list(set(history.index.get_level_values(level=0)))

    # Liquidate symbols that are not in the history dataframe anymore
    for security in self.Securities.Keys:
        if security.Value not in available_symbols:
            self.Liquidate(security, 'Not found in history request')
    """
    # Get the trade signals and YZ volatility for all securities
    trade_signals = GetTradingSignal(close_df)
    print(trade_signals)
    volatility =  GetYZVolatility(all_df)
    print(volatility)

    # Get the correlation factor
    CF_rho_bar = GetCorrelationFactor(close_df, trade_signals, available_symbols)
    print(CF_rho_bar)

    # Rebalance the portfolio according to Baltas and Kosowski suggested weights
    N_assets = len(available_symbols)
    for symbol, signal, vol in zip(available_symbols, trade_signals, volatility):
        # Baltas and Kosowski weights (Equation 19 in [1])
        weight = (signal * portfolio_target_sigma * CF_rho_bar) / (N_assets * vol)
        print (symbol,weight)
        #SetHoldings(symbol, weight)

    # Set next rebalance time
    #self.nextRebalance = Expiry.EndOfMonth(self.Time)

# %%
#print(close_df)
diff = pd.to_datetime(pd.to_datetime(close_df.index[-1]) - timedelta(90)).strftime('%Y-%m-%d')
#print (pd.to_datetime(close_df.index[-1]))
#print (diff)
past_three_month_returns = close_df.pct_change().loc[diff:]
past_three_month_returns.corr()

N_assets = len(close_df.columns)

# %%
def GetCorrelationFactor(history,trade_signals,available_symbols):
    '''
    Calculate the Correlation Factor, which is a function of the average pairwise correlation of all portfolio contituents
    - the calculation is based on past three month pairwise correlation
    - Notations:
        rho_bar - average pairwise correlation of all portfolio constituents
        CF_rho_bar - the correlation factor as a function of rho_bar'''

    # Get the past three month simple daily returns for all securities
    #settle = history.settle.unstack(level=0)
    diff = pd.to_datetime(pd.to_datetime(close_df.index[-1]) - timedelta(90)).strftime('%Y-%m-%d')
    past_three_month_returns = close_df.pct_change().loc[diff:]
    past_three_month_returns.corr()
    
    # Get number of assets 
    N_assets = len(available_symbols)

    # Get the pairwise signed correlation matrix for all assets
    correlation_matrix = past_three_month_returns.corr()

    # Calculate rho_bar
    summation = 0
    for i in range(N_assets - 1):
        for temp in range(N_assets - 1 - i):
            j = i + temp + 1
            x_i = trade_signals[i]
            x_j = trade_signals[j]
            rho_i_j = correlation_matrix.iloc[i, j]
            summation += x_i * x_j * rho_i_j

    # Equation 14 in [1]
    rho_bar = (2 * summation) / (N_assets * (N_assets - 1))

    # Calculate the correlation factor (CF_rho_bar)
    # Equation 18 in [1]
    return np.sqrt(N_assets / (1 + (N_assets - 1) * rho_bar))

# %%
available_symbols = close_df.columns
all_df = [FX_SEK,FX_DKK,FX_CHF,FX_NZD,FX_AUD,FX_CAD,FX_GBP,FX_JPY,FX_EUR]
close_df = pd.concat([FX_SEK["Last"],FX_DKK["Last"],FX_CHF["Last"],FX_NZD["Last"] ,FX_AUD["Last"],FX_CAD["Last"],FX_GBP["Last"],FX_JPY["Last"],FX_EUR["Last"]],axis =1)
available_symbols = close_df.columns

# %%
GetCorrelationFactor(close_df,GetTradingSignal(close_df),available_symbols)
# Out:
# 1.956539560752487

# %%
all_df = [FX_SEK,FX_DKK,FX_CHF,FX_NZD,FX_AUD,FX_CAD,FX_GBP,FX_JPY,FX_EUR]

## CLose Price
close_df = pd.concat([FX_SEK["Last"],FX_DKK["Last"],FX_CHF["Last"],FX_NZD["Last"] ,FX_AUD["Last"],FX_CAD["Last"],FX_GBP["Last"],FX_JPY["Last"],FX_EUR["Last"]],axis =1)
close_df.columns = {"FX_SEK","FX_DKK","FX_CHF","FX_NZD","FX_AUD","FX_CAD","FX_GBP","FX_JPY","FX_EUR"}
available_symbols = close_df.columns
print(available_symbols)
##Data
OnData(close_df,all_df,available_symbols,0.4)


#trade_signals = GetTradingSignal(close_df)
#print(trade_signals)
#volatility =  GetYZVolatility(all_df)
#print(volatility)
# Out:
# Index(['FX_CHF', 'FX_SEK', 'FX_NZD', 'FX_AUD', 'FX_JPY', 'FX_CAD', 'FX_GBP',
#        'FX_EUR', 'FX_DKK'],
#       dtype='object')
# Index(['FX_CHF', 'FX_SEK', 'FX_NZD', 'FX_AUD', 'FX_JPY', 'FX_CAD', 'FX_GBP',
#        'FX_EUR', 'FX_DKK'],
#       dtype='object')
# FX_CHF    0.723931
# FX_SEK    0.422034
# FX_NZD   -0.039119
# FX_AUD   -0.294613
# FX_JPY   -0.906419
# FX_CAD    0.883175
# FX_GBP   -0.375208
# FX_EUR   -0.429830
# FX_DKK   -0.429830
# dtype: float64
# insde
# [0.1480201864580566, 0.0953399143025246, 0.10246509546843095, 0.15253548568214184, 0.13442651520372792, 0.10226732193486733, 0.10968676546197269, 0.0940259827609974, 0.0940259827609974]
# 1.956539560752487
# FX_CHF 0.4252870301503392
# FX_SEK 0.38492738045248304
# FX_NZD -0.03319819317695445
# FX_AUD -0.16795294878745476
# FX_JPY -0.5863407283052624
# FX_CAD 0.7509585601592457
# FX_GBP -0.2974564919552864
# FX_EUR -0.3975162130368706
# FX_DKK -0.3975162130368706

# %%
all_df = [FX_CHF,FX_SEK,FX_NZD,FX_AUD,FX_JPY,FX_CAD,FX_GBP,FX_EUR,FX_DKK]
trade_signals = GetTradingSignal(close_df)
print(trade_signals)
volatility =  GetYZVolatility(all_df)
print(volatility)
# Out:
# FX_CHF    0.723931
# FX_SEK    0.422034
# FX_NZD   -0.039119
# FX_AUD   -0.294613
# FX_JPY   -0.906419
# FX_CAD    0.883175
# FX_GBP   -0.375208
# FX_EUR   -0.429830
# FX_DKK   -0.429830
# dtype: float64
# insde
# [0.10246509546843095, 0.1480201864580566, 0.15253548568214184, 0.13442651520372792, 0.0940259827609974, 0.10226732193486733, 0.10968676546197269, 0.0940259827609974, 0.0953399143025246]
