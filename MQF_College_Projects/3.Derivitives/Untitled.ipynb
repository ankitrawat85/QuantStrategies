# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## Solution 1:
# $$ Forward =  Spot * exp^{ \large r * t}
# $$
# $$
# Forward =  Spot * exp^{ (r - dividend) * t}
# $$

# %%
print ( " Risk free when divident yield is 0 : {}   ".format( math.log(105/100)/1.5))
print (  "  Risk free when divident yield is 2 % : {}".format ( (math.log(105/100)/1.5) + 0.02))
# Out:
#  Risk free when divident yield is 0 : 0.0325267761129547
#   Risk free when divident yield is 2 % : 0.0525267761129547

# %% [markdown]
# ## Solution2:

# %%
print ( " Implied Risk free rate between 1 and 2  : {} ".format((math.log(105/100)/2) - (math.log(109/100)/2)))
# Out:
#  Implied Risk free rate between 1 and 2  : -0.018693766035810182

# %% [markdown]
# ### Solution 3 :

# %% [markdown]
# Explain why American call option on the underlying which pays dividend may be optimal to exercise early? Please give an example to illustrate that.

# %% [markdown]
# Without Dividend
#
# Long Call -> Pay Cash ( at Strike) -> As it always preferable to pay cash near expiry hence early exercise is discouraged
# Long Put  -> Receive Cash ( at Strike) -> Always prefered to received cash now then later hene  early exercise is preferable. In addition is also advisable to early exercise if put is deeply in the money as on down side we have limit at 0 hence the profit is limited and have impact of Time value money and volatility
#
# With Dividend
#
# Long Call -> if have call option, then will prefer to get stock to get dividiend as post dividend price decrases hence encourage early exercise
# Long Put  -> if have Put option, then will discourage early exercise as post dividend price decrease hence Put is more valuable

# %% [markdown]
# ### Solution 4 :
# 1. Put-call parity is a principle that defines the relationship between the price of European put options and European call options of the same class, that is, with the same underlying asset, strike price, and expiration date.Put-call parity states that simultaneously holding a short European put and long European call of the same class will deliver the same return as holding one forward contract on the same underlying asset, with the same expiration, and a forward price equal to the option's strike price. If the prices of the put and call options diverge so that this relationship does not hold, an arbitrage opportunity exists, meaning that sophisticated traders can theoretically earn a risk-free profit. Such opportunities are uncommon and short-lived in liquid markets.
#
# 2.  If x is delta of call option, then delta of put option is  (Call Delta -1). Hence (  x-1)
# 3.  Vaga of Call Option = Vega of put option

# %% [markdown]
# ### Solution 5 :
# Futures interest rate is different from forward interest rate.
# When S increases, an investor who holds a long futures position makes an immediate gain because of the daily settlement procedure. The positive correlation indicates that it is likely that interest rates have also increased. The gain will therefore tend to be invested at a higher than average rate of interest.
#
# Similarly, when S decreases, the investor will incur an immediate loss. This loss will tend to be financed at a lower than average rate of interest.
# An investor holding a forward contract rather than a futures contract is not affected in this way by interest rate movements. It follows that a long futures contract will be slightly more attractive than a similar long forward contract. Hence, when S is strongly positively correlated with interest rates, futures prices will tend to be slightly higher than forward prices.
#
# When S is strongly negatively correlated with interest rates, a similar argument shows that forward prices will tend to be slightly higher than futures prices.
#
# Future Price less than Forward price

# %% [markdown]
# ### Solution 6 :
# * Call Option -In the money at expiration= N (d2) = 0.2953
# * Put Option -In the money at expiration= N (d2) = 0.7047
#
# ### Implied volatility is 20% and the riskless rate is 2.0%.
# * Call Option -In the money at expiration= N (d2) = 0.4036
# * Put Option -In the money at expiration= N (d2) = 0.5964

# %% [markdown]
# ### Solution 7 :
# * Price of at the money European call option at Strike 100 : $7.966
#
# - Price of at the money European call option at Strike 101 , volatility 0.20  : 7.515
#
# * Price of at the money European call option at Strike 101 , volatility 0.21    : 7.914
#
# * Price of at the money European call option at Strike 101 , volatility 0.21 : 8.013

# %% [markdown]
# ### Solution 8 :
# * As we need to pay 2 as fees hence it will add  in stock price i.e 100 -2. Hence now the price of options will become :  6.926
