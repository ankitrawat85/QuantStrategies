# %% [markdown]
# # Assignment 1
# - Group Member: `ANKIT RAWAT`, `JAY GUPTA`, `RAJARAJAN MOHAN`, `SHRUTI MAINDOLA`, `ZHANG SHUXIN`

# %%
import pandas as pd
import numpy  as np
import pandas_datareader as pdr
import pandas_datareader.data as web
from datetime import datetime
import random
import os

# %% [markdown]
# ## Part 1 a)Sourcing Three Years Of Price Data From A Random Set Of Five Equities.
#
# > TIINGO Was Used To Source Data

# %%
os.environ["TIINGO_API_KEY"] = "1310e73524e1c870c41cf695895e9a9ce53578a9"

# %% [markdown]
# ## Part 1 b)Storing Data Into A Dataframe

# %%
original_data = pdr.get_data_tiingo(["AMZN", "NFLX","GOOGL", "FB","AAPL"])
original_data.head()
# Out:
#                                    close     high     low    open    volume  \
# symbol date
# AMZN   2015-10-22 00:00:00+00:00  563.91  569.146  556.67  562.70   7779372
#        2015-10-23 00:00:00+00:00  599.03  619.450  595.36  617.68  10692667
#        2015-10-26 00:00:00+00:00  608.61  609.850  596.29  602.30   4269715
#        2015-10-27 00:00:00+00:00  611.01  614.710  605.53  608.60   3787136
#        2015-10-28 00:00:00+00:00  617.10  617.230  609.50  612.30   3926200
#
#                                   adjClose  adjHigh  adjLow  adjOpen  \
# symbol date
# AMZN   2015-10-22 00:00:00+00:00    563.91  569.146  556.67   562.70
#        2015-10-23 00:00:00+00:00    599.03  619.450  595.36   617.68
#        2015-10-26 00:00:00+00:00    608.61  609.850  596.29   602.30
#        2015-10-27 00:00:00+00:00    611.01  614.710  605.53   608.60
#        2015-10-28 00:00:00+00:00    617.10  617.230  609.50   612.30
#
#                                   adjVolume  divCash  splitFactor
# ...

# %% [markdown]
# ##### Resetting Index And FIxing "Date" Column Formatting

# %%
original_data.reset_index(inplace = True)
original_data["date"] = original_data["date"].dt.date

# %% [markdown]
#  ## Part 1 c) Write A Procedure To Iterate Through The Dataframe To Simulate Daily Price Stream And Print The PRices

# %%
# use 'iterrows()' to step through each day (row) of the dataframe.
lterate_Data = []
for index, row in original_data.iterrows():
     z = [row["symbol"], row["date"],row['adjClose']]
     lterate_Data.append(z)

# store the iterated data into a new dataframe
new_df = pd.DataFrame(lterate_Data)
new_df = new_df.rename(columns = {0: 'Stock Name', 1: 'Date', 2: "Adj Price"}, inplace = False)
new_df
# Out:
#      Stock Name        Date  Adj Price
# 0          AMZN  2015-10-22     563.91
# 1          AMZN  2015-10-23     599.03
# 2          AMZN  2015-10-26     608.61
# 3          AMZN  2015-10-27     611.01
# 4          AMZN  2015-10-28     617.10
# ...         ...         ...        ...
# 6280       AAPL  2020-10-13     121.10
# 6281       AAPL  2020-10-14     121.19
# 6282       AAPL  2020-10-15     120.71
# 6283       AAPL  2020-10-16     119.02
# 6284       AAPL  2020-10-19     115.98
#
# [6285 rows x 3 columns]

# %% [markdown]
# ## Part 1 d) Write A Class To Store A Single Unit Of Price Data

# %% [markdown]
# > Method 1: Store a specific unite of price data in a class and then read it.

# %%
class Stock_data:

    def __init__(self, date, open1, high, low, close, volume):
        self.date = date
        self.open1 = open1
        self.high = high
        self.low = low
        self.close = close
        self.volume = volume

# %%
a = list(original_data.iloc[1, 1:])

# %%
c = Stock_data(a[0], a[1], a[2], a[3], a[4], a[5])

# %%
print(c.date);
print(c.open1);
print(c.high);
print(c.low);
print(c.close);
print(c.volume)
# Out:
# 2015-10-23
# 599.03
# 619.45
# 595.36
# 617.68
# 10692667

# %% [markdown]
# > Method 2 : This Piece Of Data Is Randomly Pulled From The Dataframe and reveal it with A class

# %%
a = random.randint(0,len(original_data))
class FetchingRandomData:
  

    def __init__(self):
        
        self.x = original_data.iloc[a:a+1, 0:8]
        
p = FetchingRandomData()         


print(p.x)
# Out:
#      symbol        date   close    high     low    open   volume  adjClose
# 3003  GOOGL  2017-10-02  967.47  977.74  961.95  975.65  1466444    967.47

# %% [markdown]
# ## Part 1 e)Run The Iteration Procedure For Each Security And Save The Data Into A Dictionary Indexed By Datetime

# %% [markdown]
# #### For This Question, 3 ways to write the dictionary upon different understanding.
# >The first is holding an instance of the class for one security created from a row out of the iterrows() process.and indexed by 'Date'
#
# >The Second Has Only The Adjusted Prices As The Values And Datetime As The Keys.
#
# >The Third Is More Comprehensive And Has Adjusted Prices, Open, Close, High, Low And Volume As The Values And Datetime As The Keys

# %% [markdown]
# ##### First Dictionary. Set 'Date' as index. And then choose one security from the iterrated rows and then store it in a dict

# %%
new = new_df.set_index('Date')

dict(list(new[new['Stock Name'] == 'AAPL'].iterrows()))
# Out:
# {datetime.date(2015, 10, 22): Stock Name       AAPL
#  Adj Price     26.6799
#  Name: 2015-10-22, dtype: object,
#  datetime.date(2015, 10, 23): Stock Name       AAPL
#  Adj Price     27.5069
#  Name: 2015-10-23, dtype: object,
#  datetime.date(2015, 10, 26): Stock Name       AAPL
#  Adj Price     26.6291
#  Name: 2015-10-26, dtype: object,
#  datetime.date(2015, 10, 27): Stock Name       AAPL
#  Adj Price     26.4605
#  Name: 2015-10-27, dtype: object,
#  datetime.date(2015, 10, 28): Stock Name       AAPL
#  Adj Price     27.5508
#  Name: 2015-10-28, dtype: object,
#  datetime.date(2015, 10, 29): Stock Name       AAPL
#  Adj Price     27.8419
#  Name: 2015-10-29, dtype: object,
#  datetime.date(2015, 10, 30): Stock Name       AAPL
#  Adj Price     27.6039
#  Name: 2015-10-30, dtype: object,
#  datetime.date(2015, 11, 2): Stock Name      AAPL
#  Adj Price     27.992
#  Name: 2015-11-02, dtype: object,
#  datetime.date(2015, 11, 3): Stock Name       AAPL
#  Adj Price     28.3131
# ...

# %% [markdown]
# ##### Second Dictionary [Price Only Dictionary]

# %%
price_only_pivoted_df = new_df.pivot(index = "Date", columns = "Stock Name", values = ["Adj Price"])
price_only_pivoted_df
# Out:
#              Adj Price
# Stock Name        AAPL     AMZN      FB    GOOGL    NFLX
# Date
# 2015-10-22   26.679947   563.91   99.67   681.14   97.32
# 2015-10-23   27.506910   599.03  102.19   719.33  100.04
# 2015-10-26   26.629128   608.61  103.77   731.12  103.04
# 2015-10-27   26.460502   611.01  103.70   732.82  103.07
# 2015-10-28   27.550799   617.10  104.20   736.92  105.80
# ...                ...      ...     ...      ...     ...
# 2020-10-13  121.100000  3443.63  276.14  1567.07  554.09
# 2020-10-14  121.190000  3363.71  271.82  1563.44  541.45
# 2020-10-15  120.710000  3338.65  266.72  1555.47  541.94
# 2020-10-16  119.020000  3272.71  265.93  1567.70  530.79
# 2020-10-19  115.980000  3207.21  261.40  1529.95  530.72
#
# [1257 rows x 5 columns]

# %%
price_dict = price_only_pivoted_df.to_dict("index")
price_dict
# Out:
# {datetime.date(2015, 10, 22): {('Adj Price', 'AAPL'): 26.6799473706,
#   ('Adj Price', 'AMZN'): 563.91,
#   ('Adj Price', 'FB'): 99.67,
#   ('Adj Price', 'GOOGL'): 681.14,
#   ('Adj Price', 'NFLX'): 97.32},
#  datetime.date(2015, 10, 23): {('Adj Price', 'AAPL'): 27.5069102414,
#   ('Adj Price', 'AMZN'): 599.03,
#   ('Adj Price', 'FB'): 102.19,
#   ('Adj Price', 'GOOGL'): 719.33,
#   ('Adj Price', 'NFLX'): 100.04},
#  datetime.date(2015, 10, 26): {('Adj Price', 'AAPL'): 26.6291284232,
#   ('Adj Price', 'AMZN'): 608.61,
#   ('Adj Price', 'FB'): 103.77,
#   ('Adj Price', 'GOOGL'): 731.12,
#   ('Adj Price', 'NFLX'): 103.04},
#  datetime.date(2015, 10, 27): {('Adj Price', 'AAPL'): 26.460501916,
#   ('Adj Price', 'AMZN'): 611.01,
#   ('Adj Price', 'FB'): 103.7,
#   ('Adj Price', 'GOOGL'): 732.82,
#   ('Adj Price', 'NFLX'): 103.07},
#  datetime.date(2015, 10, 28): {('Adj Price', 'AAPL'): 27.5507993324,
#   ('Adj Price', 'AMZN'): 617.1,
#   ('Adj Price', 'FB'): 104.2,
# ...

# %% [markdown]
# ##### Third DIctionary [ Completed Dictionary]

# %%
complete_pivoted_df = original_data.pivot(index = "date", columns = "symbol",
                                          values = ["open", "close", "high", "low", "adjClose", "volume" ])
complete_pivoted_df
# Out:
#               open                                      close           \
# symbol        AAPL     AMZN       FB    GOOGL    NFLX    AAPL     AMZN
# date
# 2015-10-22  114.33   562.70   97.790   675.44   98.07  115.50   563.91
# 2015-10-23  116.70   617.68  101.910   750.06   97.61  119.08   599.03
# 2015-10-26  118.08   602.30  102.200   720.02  100.05  115.28   608.61
# 2015-10-27  115.40   608.60  102.940   726.57  102.58  114.55   611.01
# 2015-10-28  116.93   612.30  103.900   733.00  102.90  119.27   617.10
# ...            ...      ...      ...      ...     ...     ...      ...
# 2020-10-13  125.27  3467.99  277.580  1577.01  540.56  121.10  3443.63
# 2020-10-14  121.00  3447.00  277.620  1574.60  562.61  121.19  3363.71
# 2020-10-15  118.72  3292.01  267.600  1544.50  545.52  120.71  3338.65
# 2020-10-16  121.28  3363.23  267.375  1561.83  549.50  119.02  3272.71
# 2020-10-19  119.96  3299.61  265.530  1575.93  537.07  115.98  3207.21
#
# ...

# %%
complete_dict = complete_pivoted_df.to_dict("index")
complete_dict
# Out:
# {datetime.date(2015, 10, 22): {('open', 'AAPL'): 114.33,
#   ('open', 'AMZN'): 562.7,
#   ('open', 'FB'): 97.79,
#   ('open', 'GOOGL'): 675.44,
#   ('open', 'NFLX'): 98.07,
#   ('close', 'AAPL'): 115.5,
#   ('close', 'AMZN'): 563.91,
#   ('close', 'FB'): 99.67,
#   ('close', 'GOOGL'): 681.14,
#   ('close', 'NFLX'): 97.32,
#   ('high', 'AAPL'): 115.5,
#   ('high', 'AMZN'): 569.146,
#   ('high', 'FB'): 99.73,
#   ('high', 'GOOGL'): 688.0499,
#   ('high', 'NFLX'): 99.93,
#   ('low', 'AAPL'): 114.1,
#   ('low', 'AMZN'): 556.67,
#   ('low', 'FB'): 97.55,
#   ('low', 'GOOGL'): 671.7,
#   ('low', 'NFLX'): 96.86,
#   ('adjClose', 'AAPL'): 26.6799473706,
#   ('adjClose', 'AMZN'): 563.91,
#   ('adjClose', 'FB'): 99.67,
#   ('adjClose', 'GOOGL'): 681.14,
#   ('adjClose', 'NFLX'): 97.32,
#   ('volume', 'AAPL'): 41654089.0,
#   ('volume', 'AMZN'): 7779372.0,
#   ('volume', 'FB'): 26392075.0,
#   ('volume', 'GOOGL'): 4431595.0,
#   ('volume', 'NFLX'): 12786768.0},
# ...

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### Set up the database

# %% [markdown]
# - Create my own free cluster on MongoDB Altas namesd `Clustergogogo`<br>
# - Load the sample data to my cluster<br>

# %% [markdown]
# ### Connect to my cluster via Python

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://soothing:zsxzhm@clustergogogo.1x1sm.mongodb.net/<dbname>?retryWrites=true&w=majority")

# %% [markdown]
# ### Extract some data from my cluster

# %% [markdown]
# > Extract data from the cluster

# %%
def extract_data(database, collection):
    
    # Access to the database
    db = client[database]
    
    # Look into the collection you want check at that database
    coll = db[collection]
    
    # Ignore the '_id' and 'plot' item
    data = coll.find({}, {'_id' : 0, 'plot' : 0})
    
    return data

# %% [markdown]
# > Iterate the data to a DataFrame

# %%
def mongo_to_df(database, collection):
    my_df = pd.DataFrame(list(extract_data(database, collection)))
    df = my_df.set_index('year')
    return df

# %% [markdown]
# > Retrive the data from sample_mflix/movies

# %%
mongo_to_df('sample_mflix', 'movies')
# Out:
#                           genres  runtime  \
# year
# 1893                     [Short]      1.0
# 1903            [Short, Western]     11.0
# 1912     [Short, Drama, Fantasy]     14.0
# 1909              [Short, Drama]     14.0
# 1911  [Animation, Short, Comedy]      7.0
# ...                          ...      ...
# 2015                    [Comedy]    110.0
# 2015                  [Thriller]     90.0
# 2015                     [Drama]    102.0
# 2015               [Documentary]    115.0
# 2006    [Comedy, Drama, Romance]     91.0
#
#                                                    cast  num_mflix_comments  \
# year
# 1893                         [Charles Kayser, John Ott]                 1.0
# 1903  [A.C. Abadie, Gilbert M. 'Broncho Billy' Ander...                 NaN
# 1912  [Martin Fuller, Mrs. William Bechtel, Walter E...                 2.0
# 1909  [Frank Powell, Grace Henderson, James Kirkwood...                 1.0
# ...
