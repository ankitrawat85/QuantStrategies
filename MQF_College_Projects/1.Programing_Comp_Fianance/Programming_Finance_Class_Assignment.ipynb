# %%
import os
from datetime import datetime

import pandas
import pandas_datareader as pdr
import pandas_datareader.data as web

pandas.__version__
os.environ["TIINGO_API_KEY"] = "1310e73524e1c870c41cf695895e9a9ce53578a9"
os.environ["ALPHAVANTAGE_API_KEY"] = "5IGSC4ML6V0RDTJ4"
os.environ["QUANDL_API_KEY"] = "GMe9hEUN_9YH3Q7ANwCW-DY"

# %%
start_date = pandas.to_datetime('today').date()
end_date = pandas.to_datetime('today').date()
print(start) 
print (end )
type(end)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-56489430b1b9> in <module>
#       1 start_date = pandas.to_datetime('today').date()
#       2 end_date = pandas.to_datetime('today').date()
# ----> 3 print(start)
#       4 print (end )
#       5 type(end)
#
# NameError: name 'start' is not defined

# %%
df = pdr.get_data_tiingo(['AMZN', 'NFLX', 'GOOGL', 'FB', 'AAPL'],start=start_date, end=end_date, api_key=os.getenv('TIINGO_API_KEY'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-487ce0ea4caf> in <module>
# ...

# %%
df.reset_index(inplace = True)
df["date"] = df["date"].dt.date

# %%
_df = df.pivot( "date","symbol","adjClose")

# %%
pandas.to_datetime('today').date()
# Out:
# datetime.date(2020, 10, 16)

# %%
df = pdr.get_data_tiingo(['AMZN', 'NFLX', 'GOOGL', 'FB', 'AAPL'],start=datetime(2017, 10, 1), end=datetime(2020, 10, 1), api_key=os.getenv('TIINGO_API_KEY'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-56b9364c4cc8> in <module>
# ----> 1 df = pdr.get_data_tiingo(['AMZN', 'NFLX', 'GOOGL', 'FB', 'AAPL'],start=datetime(2017, 10, 1), end=datetime(2020, 10, 1), api_key=os.getenv('TIINGO_API_KEY'))
#
# NameError: name 'pdr' is not defined

# %%
## Current Price
