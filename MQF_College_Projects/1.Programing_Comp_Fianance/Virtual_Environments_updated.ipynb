# %% [markdown]
# # Virtual Environments
#
# With conda, you can create, export, list, remove, and update environments that have different versions of Python and/or packages installed in them. Switching or moving between environments is called activating the environment. You can also share an environment file.

# %% [markdown]
# ## Links
#
# - https://towardsdatascience.com/getting-started-with-python-environments-using-conda-32e9f2779307
# - https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html
# - https://heartbeat.fritz.ai/creating-python-virtual-environments-with-conda-why-and-how-180ebd02d1db
# - https://www.youtube.com/watch?v=1VVCd0eSkYc
#
#
# Environment is set of packages and Python library.

# %% [markdown]
# Update conda to the current version

# %%
# !conda update conda -y

# %% [markdown]
# Verify conda is installed, check version number

# %%
# !conda info
# Out:
#      active environment : base
#     active env location : /Users/ankitrawat/opt/anaconda3
#             shell level : 1
#        user config file : /Users/ankitrawat/.condarc
#  populated config files : /Users/ankitrawat/.condarc
#           conda version : 4.9.2
#     conda-build version : 3.18.11
#          python version : 3.7.6.final.0
#        virtual packages : __osx=10.16=0
#                           __unix=0=0
#                           __archspec=1=x86_64
#        base environment : /Users/ankitrawat/opt/anaconda3  (writable)
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /Users/ankitrawat/opt/anaconda3/pkgs
#                           /Users/ankitrawat/.conda/pkgs
# ...

# %% [markdown]
# Get a list of all my environments. The active environment is shown with *

# %%
# !conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /Users/ankitrawat/opt/anaconda3
# [environment-name]       /Users/ankitrawat/opt/anaconda3/envs/[environment-name]
# python3.6                /Users/ankitrawat/opt/anaconda3/envs/python3.6
# snakes                   /Users/ankitrawat/opt/anaconda3/envs/snakes
# tensor                   /Users/ankitrawat/opt/anaconda3/envs/tensor
# tf                       /Users/ankitrawat/opt/anaconda3/envs/tf

# %% [markdown]
# List all packages and versions installed in active environment

# %%
# !conda list
# Out:
# # packages in environment at /Users/ankitrawat/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# absl-py                   0.12.0                   pypi_0    pypi
# aiohttp                   3.7.2                    pypi_0    pypi
# alabaster                 0.7.12                   py37_0
# alpha-vantage             2.2.0                    pypi_0    pypi
# anaconda                  2020.02                  py37_0
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.9.12                   py37_0
# anaconda-project          0.8.4                      py_0
# appdirs                   1.4.4                    pypi_0    pypi
# applaunchservices         0.2.1                      py_0
# appnope                   0.1.0                    py37_0
# appscript                 1.1.0            py37h1de35cc_0
# ...

# %% [markdown]
# Save environment to a text file

# %%
# !conda list --explicit > my-env.txt

# %% [markdown]
# Create a new environment named ml_env, install Python and libraries

# %%
 # !conda create --name research_tensor python=3.6 -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/ankitrawat/opt/anaconda3/envs/research_tensor
#
#   added / updated specs:
#     - python=3.6
#
#
# The following NEW packages will be INSTALLED:
#
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2021.1.19-hecd8cb5_1
#   certifi            pkgs/main/osx-64::certifi-2020.12.5-py36hecd8cb5_0
#   libcxx             pkgs/main/osx-64::libcxx-10.0.0-1
#   libffi             pkgs/main/osx-64::libffi-3.3-hb1e8313_2
#   ncurses            pkgs/main/osx-64::ncurses-6.2-h0a44026_1
#   openssl            pkgs/main/osx-64::openssl-1.1.1k-h9ed2024_0
#   pip                pkgs/main/osx-64::pip-21.0.1-py36hecd8cb5_0
#   python             pkgs/main/osx-64::python-3.6.13-h88f2d9e_0
#   readline           pkgs/main/osx-64::readline-8.1-h9ed2024_0
#   setuptools         pkgs/main/osx-64::setuptools-52.0.0-py36hecd8cb5_0
#   sqlite             pkgs/main/osx-64::sqlite-3.35.4-hce871da_0
# ...

# %%
# !conda create --name bokeh_env python=3 numpy scipy pandas bokeh ipykernel nb_conda_kernels -y

# %% [markdown]
# You then need to run this line to link it to the Kernel dropdown menu above. You may have to reload the notebook.

# %%
# !python -m ipykernel install --user --name research_tensor --display-name "research_tensor"

# %% [markdown]
# Once you are in the environment, you can add packages via conda or via pip.

# %%
# !conda install numpy
# Out:
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::python-language-server==0.31.7=py37_0
#   - defaults/osx-64::scipy==1.4.1=py37h9fa6033_0
#   - defaults/osx-64::matplotlib==3.1.3=py37_0
#   - defaults/osx-64::pyrsistent==0.15.7=py37h1de35cc_0
#   - defaults/osx-64::bokeh==1.4.0=py37_0
#   - defaults/osx-64::pandas==1.0.1=py37h6c726b0_0
#   - defaults/osx-64::notebook==6.0.3=py37_0
#   - defaults/osx-64::bottleneck==1.3.2=py37h776bbcc_0
#   - defaults/osx-64::jupyter==1.0.0=py37_7
#   - defaults/osx-64::spyder==4.0.1=py37_0
#   - defaults/osx-64::jupyter_core==4.6.1=py37_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py37_0
#   - defaults/osx-64::conda-package-handling==1.6.0=py37h1de35cc_0
#   - defaults/noarch::sphinx==2.4.0=py_0
#   - defaults/osx-64::cycler==0.10.0=py37_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
# ...

# %%
# !pip install tensorflow-gpu==1.15.0 tensorflow==1.15.0 stable-baselines gym-anytrading gym

# %%
# !conda info --envs

# %% [markdown]
# If you want to remove an environment you can run the following.

# %%
# !conda remove --name ml_env --all -y

# %%
# !conda remove --name tf
# Out:
# CondaValueError: no package names supplied,
#        try "conda remove -h" for more details

# %% [markdown]
# ## yml files

# %%
# !cat environment.yml
# Out:
# name: smu_env
# channels:
# - conda-forge
# dependencies:
# - python=3.7
# - pip

# %%
# !conda env export --file test.yml

# %% [markdown]
# You can create an environment file (environment.yml) manually to share with others.

# %%
# !conda env create --file environment.yml

# %%
# !python -m ipykernel install --user --name smu_env --display-name "SMU"

# %%
# !conda install <package(s)>

or

# !pip install <package(s)>
