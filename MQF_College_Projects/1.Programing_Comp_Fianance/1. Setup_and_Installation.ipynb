# %% [markdown]
# # 1. Setup and Installation

# %% [markdown]
# The easiest way to install Python with scientic packages is with the Anaconda distribution:
# - Mac OS, Windows, Linux
# - Python 3 (we use 3.7 in this course)
# - https://www.anaconda.com/download/
# - Includes hundreds of packages by default.
# - Easily manage "environments" (sets of packages) for each project.
# - Includes Spyder and Jupyter, and R as an option.

# %% [markdown]
# ## Visual Studio code
#
# https://code.visualstudio.com/docs/python/python-tutorial
