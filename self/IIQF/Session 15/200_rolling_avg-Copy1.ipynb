# %%
- MACD indicator
- Moving average
- Moving average convergence divergence

# %% [markdown]
# [rolling window](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html)

# %%
import pandas as pd
import numpy as np

# %%
file_name = folder_name + "/" + symbol + ".csv" 
    data = pd.read_csv(file_name) 
    data[index_col] = pd.to_datetime(data[index_col]) 
    data = data.set_index(index_col)

# %%
fol

# %%
import pandas as pd

# %%
import mod_my_utils.read_write_data as mu

# %%
folder_name = 'data/'
stock_name = 'aapl'

# %%
file_name = folder_name + "/" + symbol + ".csv" 
    data = pd.read_csv(file_name) 
    data[index_col] = pd.to_datetime(data[index_col]) 
    data = data.set_index(index_col)

# %%
folder_name + "/" + stock_name + ".csv"
# Out:
# 'data//aapl.csv'

# %%
file_name = folder_name + "/" + stock_name + ".csv"

# %%
data = pd.read_csv(file_name)

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.head()
# Out:
#         Date    Open    High     Low     Close      Volume  Ex-Dividend  \
# 0 2007-12-03  181.86  184.14  177.70  178.8600  34338200.0          0.0
# 1 2007-12-04  177.15  180.90  176.99  179.8100  27635700.0          0.0
# 2 2007-12-05  182.89  186.00  182.41  185.5000  31871500.0          0.0
# 3 2007-12-06  186.19  190.10  186.12  189.9528  32136100.0          0.0
# 4 2007-12-07  190.54  194.99  188.04  194.3000  38073800.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# 0          1.0  23.371545  23.664556  22.836927   22.986003  240367400.0
# 1          1.0  22.766244  23.248171  22.745682   23.108091  193449900.0
# 2          1.0  23.503914  23.903592  23.442227   23.839335  223100500.0
# 3          1.0  23.928010  24.430500  23.919014   24.411582  224952700.0
# 4          1.0  24.487046  25.058933  24.165761   24.970258  266516600.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         2517 non-null   datetime64[ns]
#  1   Open         2517 non-null   float64
#  2   High         2517 non-null   float64
#  3   Low          2517 non-null   float64
#  4   Close        2517 non-null   float64
#  5   Volume       2517 non-null   float64
#  6   Ex-Dividend  2517 non-null   float64
#  7   Split Ratio  2517 non-null   float64
#  8   Adj. Open    2517 non-null   float64
#  9   Adj. High    2517 non-null   float64
#  10  Adj. Low     2517 non-null   float64
#  11  Adj. Close   2517 non-null   float64
#  12  Adj. Volume  2517 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 255.8 KB

# %%
data['Open'].plot()
# Out:
# <AxesSubplot:>

# %%
 data = data.set_index('Date')

# %%
data.head()
# Out:
#               Open    High     Low     Close      Volume  Ex-Dividend  \
# Date
# 2007-12-03  181.86  184.14  177.70  178.8600  34338200.0          0.0
# 2007-12-04  177.15  180.90  176.99  179.8100  27635700.0          0.0
# 2007-12-05  182.89  186.00  182.41  185.5000  31871500.0          0.0
# 2007-12-06  186.19  190.10  186.12  189.9528  32136100.0          0.0
# 2007-12-07  190.54  194.99  188.04  194.3000  38073800.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2007-12-03          1.0  23.371545  23.664556  22.836927   22.986003
# 2007-12-04          1.0  22.766244  23.248171  22.745682   23.108091
# 2007-12-05          1.0  23.503914  23.903592  23.442227   23.839335
# 2007-12-06          1.0  23.928010  24.430500  23.919014   24.411582
# 2007-12-07          1.0  24.487046  25.058933  24.165761   24.970258
#
#             Adj. Volume
# Date
# 2007-12-03  240367400.0
# 2007-12-04  193449900.0
# 2007-12-05  223100500.0
# 2007-12-06  224952700.0
# 2007-12-07  266516600.0

# %%
data['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
def get_price_csv(folder_name, symbol, index_col):
    """ 
    Get 'Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio',
       'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'
       
    Parameters
    --------------------------------
    Input Argument: 
    Folder name : Path of the folder where csv file is added
    symbol : name of the stock
    index_col: Column for indexing
    
    Output: 
    Stock data with date as index 
    """ 
    file_name = folder_name + "/" + symbol + ".csv" 
    data = pd.read_csv(file_name) 
    data[index_col] = pd.to_datetime(data[index_col]) 
    data = data.set_index(index_col)
    print("stock name: ", symbol) 
    return data

# %%
get_price_csv(folder_name, stock_name, index_col='Date').plot()
# Out:
# stock name:  aapl
# <AxesSubplot:xlabel='Date'>

# %%
help(get_price_csv)
# Out:
# Help on function get_price_csv in module __main__:
#
# get_price_csv(folder_name, symbol, index_col)
#     Get 'Open', 'High', 'Low', 'Close', 'Volume', 'Ex-Dividend', 'Split Ratio',
#        'Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume'
#
#     Parameters
#     --------------------------------
#     Input Argument:
#     Folder name : Path of the folder where csv file is added
#     symbol : name of the stock
#     index_col: Column for indexing
#
#     Output:
#     Stock data with date as index

# %%
folder_path
# Out:
# 'data/'

# %%
stock_name
# Out:
# 'aapl'

# %%
'data//AAPL.csv'

# %%
'data//' + "AAPL" + ".csv"
# Out:
# 'data//AAPL.csv'

# %%
stock_data = mu.get_stock_csv(folder_name=folder_path, symbol=stock_name, index_col='Date')
# Out:
# stock name:  aapl

# %%
data = stock_data[["Adj. Close"]].copy()
data.columns = ["Price"] 
data.head()
# Out:
#                 Price
# Date
# 2007-12-03  22.986003
# 2007-12-04  23.108091
# 2007-12-05  23.839335
# 2007-12-06  24.411582
# 2007-12-07  24.970258

# %%
data.head()
# Out:
#                 Price
# Date
# 2007-12-03  22.986003
# 2007-12-04  23.108091
# 2007-12-05  23.839335
# 2007-12-06  24.411582
# 2007-12-07  24.970258

# %%
data.rolling(window=10)
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
data.head()
# Out:
#               Open    High     Low     Close      Volume  Ex-Dividend  \
# Date
# 2007-12-03  181.86  184.14  177.70  178.8600  34338200.0          0.0
# 2007-12-04  177.15  180.90  176.99  179.8100  27635700.0          0.0
# 2007-12-05  182.89  186.00  182.41  185.5000  31871500.0          0.0
# 2007-12-06  186.19  190.10  186.12  189.9528  32136100.0          0.0
# 2007-12-07  190.54  194.99  188.04  194.3000  38073800.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2007-12-03          1.0  23.371545  23.664556  22.836927   22.986003
# 2007-12-04          1.0  22.766244  23.248171  22.745682   23.108091
# 2007-12-05          1.0  23.503914  23.903592  23.442227   23.839335
# 2007-12-06          1.0  23.928010  24.430500  23.919014   24.411582
# 2007-12-07          1.0  24.487046  25.058933  24.165761   24.970258
#
#             Adj. Volume
# Date
# 2007-12-03  240367400.0
# 2007-12-04  193449900.0
# 2007-12-05  223100500.0
# 2007-12-06  224952700.0
# 2007-12-07  266516600.0

# %%
data.rolling(window=5)
# Out:
# Rolling [window=5,center=False,axis=0]

# %%
data.rolling(window=5).mean()
# Out:
#                Open     High        Low      Close      Volume  Ex-Dividend  \
# Date
# 2007-12-03      NaN      NaN        NaN        NaN         NaN          NaN
# 2007-12-04      NaN      NaN        NaN        NaN         NaN          NaN
# 2007-12-05      NaN      NaN        NaN        NaN         NaN          NaN
# 2007-12-06      NaN      NaN        NaN        NaN         NaN          NaN
# 2007-12-07  183.726  187.226  182.25200  185.68456  32811060.0          0.0
# ...             ...      ...        ...        ...         ...          ...
# 2017-11-27  172.916  173.968  172.27518  173.42800  20081992.8          0.0
# 2017-11-28  173.718  174.830  172.73518  174.04600  21980803.8          0.0
# 2017-11-29  174.088  174.674  172.01118  173.31400  25163374.4          0.0
# 2017-11-30  173.502  174.102  171.08918  172.69200  28198393.2          0.0
# 2017-12-01  172.472  173.336  169.86000  171.90800  33311105.4          0.0
#
#             Split Ratio   Adj. Open  Adj. High    Adj. Low  Adj. Close  \
# Date
# 2007-12-03          NaN         NaN        NaN         NaN         NaN
# 2007-12-04          NaN         NaN        NaN         NaN         NaN
# 2007-12-05          NaN         NaN        NaN         NaN         NaN
# 2007-12-06          NaN         NaN        NaN         NaN         NaN
# 2007-12-07          1.0   23.611352   24.06115   23.421922   23.863054
# ...                 ...         ...        ...         ...         ...
# 2017-11-27          1.0  172.916000  173.96800  172.275180  173.428000
# 2017-11-28          1.0  173.718000  174.83000  172.735180  174.046000
# 2017-11-29          1.0  174.088000  174.67400  172.011180  173.314000
# 2017-11-30          1.0  173.502000  174.10200  171.089180  172.692000
# 2017-12-01          1.0  172.472000  173.33600  169.860000  171.908000
#
#             Adj. Volume
# Date
# 2007-12-03          NaN
# 2007-12-04          NaN
# 2007-12-05          NaN
# 2007-12-06          NaN
# 2007-12-07  229677420.0
# ...                 ...
# 2017-11-27   20081992.8
# 2017-11-28   21980803.8
# 2017-11-29   25163374.4
# 2017-11-30   28198393.2
# 2017-12-01   33311105.4
#
# [2517 rows x 12 columns]

# %%
data.rolling(window=5).max()
# Out:
#               Open    High       Low   Close      Volume  Ex-Dividend  \
# Date
# 2007-12-03     NaN     NaN       NaN     NaN         NaN          NaN
# 2007-12-04     NaN     NaN       NaN     NaN         NaN          NaN
# 2007-12-05     NaN     NaN       NaN     NaN         NaN          NaN
# 2007-12-06     NaN     NaN       NaN     NaN         NaN          NaN
# 2007-12-07  190.54  194.99  188.0400  194.30  38073800.0          0.0
# ...            ...     ...       ...     ...         ...          ...
# 2017-11-27  175.10  175.50  174.6459  174.97  24997274.0          0.0
# 2017-11-28  175.10  175.50  174.6459  174.97  25468442.0          0.0
# 2017-11-29  175.10  175.50  174.6459  174.97  40788324.0          0.0
# 2017-11-30  175.10  175.50  174.6459  174.97  40788324.0          0.0
# 2017-12-01  175.05  175.08  173.3400  174.09  40788324.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# Date
# 2007-12-03          NaN         NaN         NaN         NaN         NaN
# 2007-12-04          NaN         NaN         NaN         NaN         NaN
# 2007-12-05          NaN         NaN         NaN         NaN         NaN
# 2007-12-06          NaN         NaN         NaN         NaN         NaN
# 2007-12-07          1.0   24.487046   25.058933   24.165761   24.970258
# ...                 ...         ...         ...         ...         ...
# 2017-11-27          1.0  175.100000  175.500000  174.645900  174.970000
# 2017-11-28          1.0  175.100000  175.500000  174.645900  174.970000
# 2017-11-29          1.0  175.100000  175.500000  174.645900  174.970000
# 2017-11-30          1.0  175.100000  175.500000  174.645900  174.970000
# 2017-12-01          1.0  175.050000  175.080000  173.340000  174.090000
#
#             Adj. Volume
# Date
# 2007-12-03          NaN
# 2007-12-04          NaN
# 2007-12-05          NaN
# 2007-12-06          NaN
# 2007-12-07  266516600.0
# ...                 ...
# 2017-11-27   24997274.0
# 2017-11-28   25468442.0
# 2017-11-29   40788324.0
# 2017-11-30   40788324.0
# 2017-12-01   40788324.0
#
# [2517 rows x 12 columns]

# %%
data.rolling(window=5)

# %%
data.head()
# Out:
#                 Price     ewm_10
# Date
# 2007-12-03  22.986003  22.986003
# 2007-12-04  23.108091  23.008201
# 2007-12-05  23.839335  23.159316
# 2007-12-06  24.411582  23.387001
# 2007-12-07  24.970258  23.674866

# %%
def square(item):
    return item * item

# %%
data['short_ewm_10'] = data['Price'].ewm(span=10, adjust=False).mean()
data['long_ewm_20'] = data['Price'].ewm(span=20, adjust=False).mean()
data.head()
# Out:
#                 Price     ewm_10  short_ewm_10  long_ewm_20
# Date
# 2007-12-03  22.986003  22.986003     22.986003    22.986003
# 2007-12-04  23.108091  23.008201     23.008201    22.997630
# 2007-12-05  23.839335  23.159316     23.159316    23.077793
# 2007-12-06  24.411582  23.387001     23.387001    23.204820
# 2007-12-07  24.970258  23.674866     23.674866    23.372957
